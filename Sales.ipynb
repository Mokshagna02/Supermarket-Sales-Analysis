# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\HP\\Downloads\\supermarket_sales.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
df['Day'] = df['Date'].dt.day
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

# %%
df['Hour'] = df.Time.apply(lambda x: x.split(':')[0])
df['Minutes'] = df.Time.apply(lambda x: x.split(':')[1])

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  ...  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  ...
# 1  Electronic accessories       15.28         5   3.8200   80.2200  ...
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  ...
# 3       Health and beauty       58.22         8  23.2880  489.0480  ...
# 4       Sports and travel       86.31         7  30.2085  634.3785  ...
#
#      cogs gross margin percentage gross income  Rating  Day  Month  Year  \
# 0  522.83                4.761905      26.1415     9.1    5      1  2019
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# Day                        0
# Month                      0
# Year                       0
# Hour                       0
# Minutes                    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total  \
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749
# min      10.080000     1.000000     0.508500    10.678500
# 25%      32.875000     3.000000     5.924875   124.422375
# 50%      55.230000     5.000000    12.088000   253.848000
# 75%      77.935000     8.000000    22.445250   471.350250
# max      99.960000    10.000000    49.650000  1042.650000
# std      26.494628     2.923431    11.708825   245.885335
#
#                              Date        cogs  gross margin percentage  \
# count                        1000  1000.00000             1.000000e+03
# mean   2019-02-14 00:05:45.600000   307.58738             4.761905e+00
# min           2019-01-01 00:00:00    10.17000             4.761905e+00
# 25%           2019-01-24 00:00:00   118.49750             4.761905e+00
# 50%           2019-02-13 00:00:00   241.76000             4.761905e+00
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
branch_cunt = df['Branch'].value_counts()
branch_cunt
# Out:
# Branch
# A    340
# B    332
# C    328
# Name: count, dtype: int64

# %%
sns.countplot(x='Branch',data=df)
plt.title('Branch Count')
plt.show()

# %%
city_cunt=df['City'].value_counts()
city_cunt
# Out:
# City
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: count, dtype: int64

# %%
sns.countplot(x='City',data=df)
plt.title('City Count')
plt.show()

# %%
custmr_cunt = df['Customer type'].value_counts()
custmr_cunt
# Out:
# Customer type
# Member    501
# Normal    499
# Name: count, dtype: int64

# %%
sns.countplot(x='Customer type',data=df)
plt.title('Num of customers')
plt.show()

# %%
gender_cunt = df['Gender'].value_counts()
gender_cunt
# Out:
# Gender
# Female    501
# Male      499
# Name: count, dtype: int64

# %%
sns.countplot(x='Gender',data=df)
plt.title('Gender Count')
plt.show()

# %%
prdt_cunt = df['Product line'].value_counts()
prdt_cunt
# Out:
# Product line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: count, dtype: int64

# %%
sns.countplot(x='Product line',data=df,palette='pastel')
plt.title('Num of Each Product')
plt.xticks(rotation=45)
plt.show()

# %%
# Total sales by branch
sales_by_branch = df.groupby('Branch')['Total'].sum().sort_values(ascending=False)

print(sales_by_branch)
# Out:
# Branch
# C    110568.7065
# A    106200.3705
# B    106197.6720
# Name: Total, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=sales_by_branch.index,y=sales_by_branch.values,palette='Greens_r')
plt.title('Sales in each Branch')
plt.ylabel('Total Sales')
plt.xlabel('Branch')
plt.show()

# %%
# Total sales by city
sales_by_city = df.groupby('City')['Total'].sum().sort_values(ascending=False)

print(sales_by_city)
# Out:
# City
# Naypyitaw    110568.7065
# Yangon       106200.3705
# Mandalay     106197.6720
# Name: Total, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=sales_by_city.index,y=sales_by_city.values,palette='Reds_r')
plt.title('Sales in each City')
plt.xlabel('city')
plt.ylabel('sales')
plt.show()

# %%
sales_by_product=df.groupby('Product line')['Total'].sum().sort_values(ascending=False)
sales_by_product
# Out:
# Product line
# Food and beverages        56144.8440
# Sports and travel         55122.8265
# Electronic accessories    54337.5315
# Fashion accessories       54305.8950
# Home and lifestyle        53861.9130
# Health and beauty         49193.7390
# Name: Total, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=sales_by_product.index,y=sales_by_product.values,palette='YlGnBu_r')
plt.title('Product Sales')
plt.xlabel('Products')
plt.ylabel('sales')
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x='Payment',data=df,palette='Purples_r')
plt.title('Payment Methods')
plt.show()

# %%
sales_by_cstmr=df.groupby('Customer type')['Total'].sum().sort_values(ascending=False)
sales_by_cstmr
# Out:
# Customer type
# Member    164223.444
# Normal    158743.305
# Name: Total, dtype: float64

# %%
plt.figure(figsize=(8,6))
plt.pie(sales_by_cstmr.values,labels=sales_by_cstmr.index,autopct='%.1f%%',startangle=90)
plt.title('sales_by_Customer')
plt.show()

# %%
sns.countplot(x='Customer type',hue='Branch',data=df)
plt.title('Types of customers by Branch')
plt.show()

# %%
sns.barplot(x='Product line',y='Rating',data=df,palette='deep')
plt.title('Product Ratings')
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(x='Product line',y='gross income',data=df,palette='Paired')
plt.title('Gross Income for Each Product')
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x='Customer type',hue='Gender',data=df)
plt.title('Gender across Customer Types')
plt.show()

# %%
sns.countplot(x='Product line',hue='Gender',data=df)
plt.title('Gender across Each Product')
plt.xticks(rotation=45)
plt.show()

# %%
# Adding a 'Day Name' column to the dataframe
df['Day name'] = df['Date'].dt.day_name()

# Analyzing sales by day of the week
sales_by_day = df.groupby('Day name')['Total'].sum().sort_values(ascending=False)

print(sales_by_day)
# Out:
# Day name
# Saturday     56120.8095
# Tuesday      51482.2455
# Thursday     45349.2480
# Sunday       44457.8925
# Friday       43926.3405
# Wednesday    43731.1350
# Monday       37899.0780
# Name: Total, dtype: float64

# %%
sns.barplot(x=sales_by_day.index,y=sales_by_day.values,palette='viridis')
plt.title('Sales Per Day')
plt.xlabel('Days')
plt.ylabel('Sales')
plt.show()
